# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %% [markdown]
# # Setul de date
#
# Vom folosi setul de date Iris Species in care pe baza caracteristicilor plantelor dorim sa le clasificam in 3 clase:
# - iris-setosa
# - iris-versicolor
# - iris-virginica
#
# Setul de date poate fi gasit si pe link-ul urmator:
#
# https://www.kaggle.com/uciml/iris

# %%
data = load_iris(return_X_y=True, as_frame=True)

# %%
X, y = data

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
y.value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %% [markdown]
# # Verificam daca avem valori nule

# %%
X.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
list(y.value_counts().keys())
# Out:
# [0, 1, 2]

# %% [markdown]
# # Verificam distributiile variabilelor continue

# %%
columns = list(X.columns)
classes = list(y.value_counts().keys())
for column in columns:
    plt.figure()
    for cls in classes:
        sns.distplot(X[column][y==cls], label=str(cls))
        plt.title(column)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16188\3335628915.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X[column][y==cls], label=str(cls))
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16188\3335628915.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
columns = list(X.columns)
for column in columns:
    plt.figure()
    sns.barplot(X[column])
    plt.title(column)

# %%
sns.heatmap(X.corr(), annot=True, cmap='Blues')
# Out:
# <Axes: >
